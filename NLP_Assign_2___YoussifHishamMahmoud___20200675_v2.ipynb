# %% [markdown]
# # **Random Document Generator using GPT transformer model**

# %%
from transformers import pipeline

# %%
generator = pipeline('text-generation', model="openai-community/gpt2")

# %% [markdown]
# # **Document Generation**

# %%
document_1 = generator('the history of the middle east', max_length = 600,  num_return_sequences=1, truncation=True)
document_1 = document_1[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
document_2 = generator('artificial intelligence revolution', max_length = 600,  num_return_sequences=1, truncation=True)
document_2 = document_2[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(document_1)
print(document_2)
# Out:
# the history of the middle east, which began with the Islamic invasion of Iraq. This is a historical problem that still needs to be solved or there will be a change of course."
#
# Turkey's parliament, meanwhile, has agreed to convene a committee to report the findings of the report into corruption and other corruption issues during the Erdogan presidency. An investigative panel headed by Justice Minister Numan Kurtulmus said that the corruption has resulted in up to $100 million (£57 million) in money laundering, a charge it charged is against the prime minister.
#
# The court case has sparked widespread speculation. For instance, a prominent figure in the city of Gaziantep, Mevlut Cavusoglu, accused a newspaper of inciting anger over the coup in July, and the Justice Minister charged a former editor, Efrem Ozbilic, with leaking information to the media.
#
# The Justice Minister's investigation into the coup plot, and Cavusoglu's decision to leave the country last year, was seen by some critics as an attempt to protect Turkish citizens from prosecution by Ankara.
#
# But opposition leaders have called on the public to support the investigation.
#
# "The judicial investigation is a very thorough process," Turkish Prime Minister Binali Yildirim said on Monday before a three-hour meeting with the country's foreign minister.
# artificial intelligence revolution: a way to find answers. We have now begun our own deep learning revolution. In this article, some background on what we are doing as a company: What is artificial intelligence and what does it mean for our business processes? We have decided that we want to build products that enable you to find out. It's a very collaborative process, with users and companies working together to try and provide the best possible products. Our aim is to develop a technology that will enable you to find the best products and to test them.
#
# I'm going to start by saying that we already have a great amount of talent at the forefront of new products; We're talking about thousands of people working in different ways around the world and at different stages of the process. It's happening rapidly. But we have to find a way to do it. In part we've been talking about how to better represent the data; in part we're talking about how we can take the data and leverage that data to create more relevant products that are valuable for different businesses. We're at the stage where we have to know things. Some of them may be obvious and others may not be obvious. Our primary goal is to understand the relevant, relevant data. So we started by talking about things that our customers ask about. People ask about: "How can I better serve my customers?" We have a different focus within the business to have that experience. We have to know the key ideas that we have in place to understand the business, as well as what we will do if we get too far ahead in that or too soon in that topic. We're going to be looking for new insights that might not be obvious to customers.
#
# I'll get to what we are trying to do. We have already tried to build and test various models for how to differentiate different types of business or businesses. It's time for us to make that leap and be flexible with those models, if necessary, to differentiate whether they are useful. I'll cover a couple of things. First, to be really thorough: You cannot just use models that are simple and make everything look like something that you have the same or similar value. When we introduce people to certain models it makes it harder to pick the one that looks better for them. I won't go into all of that, because that's only a topic for a minute. It should be clear that there are a lot of other benefits for your business, for your customers, or for your customers.
#
# Now let us focus on a model that's different from what the model of the same price point of the same product might imply. What we will do is to look at different types of business. Why: We are going to do this because we are going to help people become more productive in their business processes. It's also going to help us understand the important business things that you are going to find as a business. The kind of business you

# %% [markdown]
# # **preprocessing of data**

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def clean_data(text):
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))

    #Normalizing text to lowercase
    text = text.lower()

    #Remove symbols, characters, and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    #Tokenization
    tokens = word_tokenize(text)

    #Lemmatization and stop words cleaning
    cleaned_tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]

    #Full corpus
    cleaned_text = ' '.join(cleaned_tokens)

    return cleaned_text

# %%
def get_unique_words(text):
    words = word_tokenize(text)
    unique_words = set(words)
    return unique_words

# %%
document_1_cleaned = clean_data(document_1)
document_2_cleaned = clean_data(document_2)

# %%
print(document_1_cleaned)
print(document_2_cleaned)
# Out:
# history middle east began islamic invasion iraq historical problem still need solved change course turkey parliament meanwhile agreed convene committee report finding report corruption corruption issue erdogan presidency investigative panel headed justice minister numan kurtulmus said corruption resulted million million money laundering charge charged prime minister court case sparked widespread speculation instance prominent figure city gaziantep mevlut cavusoglu accused newspaper inciting anger coup july justice minister charged former editor efrem ozbilic leaking information medium justice minister investigation coup plot cavusoglus decision leave country last year seen critic attempt protect turkish citizen prosecution ankara opposition leader called public support investigation judicial investigation thorough process turkish prime minister binali yildirim said monday threehour meeting country foreign minister
# artificial intelligence revolution way find answer begun deep learning revolution article background company artificial intelligence mean business process decided want build product enable find collaborative process user company working together try provide best possible product aim develop technology enable find best product test im going start saying already great amount talent forefront new product talking thousand people working different way around world different stage process happening rapidly find way part weve talking better represent data part talking take data leverage data create relevant product valuable different business stage know thing may obvious others may obvious primary goal understand relevant relevant data started talking thing customer ask people ask better serve customer different focus within business experience know key idea place understand business well get far ahead soon topic going looking new insight might obvious customer ill get trying already tried build test various model differentiate different type business business time u make leap flexible model necessary differentiate whether useful ill cover couple thing first really thorough use model simple make everything look like something similar value introduce people certain model make harder pick one look better wont go thats topic minute clear lot benefit business customer customer let u focus model thats different model price point product might imply look different type business going going help people become productive business process also going help u understand important business thing going find business kind business

# %%
full_corpus = [document_1_cleaned, document_2_cleaned]

# %% [markdown]
# # **Extracting Unique words from the corpus**

# %%
unique_words = set()
for doc in full_corpus :
  unique_words = unique_words.union(set(doc.split()))
print(unique_words)
print(len(unique_words))
# Out:
# {'anger', 'protect', 'want', 'looking', 'collaborative', 'iraq', 'stage', 'resulted', 'benefit', 'valuable', 'pick', 'need', 'city', 'important', 'might', 'clear', 'mean', 'newspaper', 'value', 'imply', 'help', 'instance', 'leap', 'investigative', 'use', 'im', 'customer', 'deep', 'build', 'sparked', 'kind', 'focus', 'price', 'make', 'middle', 'obvious', 'ozbilic', 'topic', 'time', 'going', 'yildirim', 'committee', 'country', 'experience', 'judicial', 'attempt', 'simple', 'thousand', 'lot', 'part', 'decision', 'try', 'provide', 'cover', 'said', 'support', 'productive', 'talking', 'former', 'forefront', 'critic', 'course', 'meeting', 'serve', 'information', 'july', 'binali', 'data', 'primary', 'convene', 'headed', 'insight', 'speculation', 'business', 'world', 'really', 'gaziantep', 'product', 'minister', 'inciting', 'know', 'like', 'working', 'others', 'ahead', 'thats', 'create', 'develop', 'company', 'whether', 'take', 'tried', 'idea', 'threehour', 'differentiate', 'accused', 'coup', 'figure', 'leaking', 'medium', 'first', 'talent', 'happening', 'issue', 'investigation', 'cavusoglu', 'leader', 'public', 'begun', 'prominent', 'turkish', 'leverage', 'may', 'plot', 'article', 'corruption', 'report', 'key', 'prime', 'soon', 'u', 'well', 'also', 'million', 'aim', 'began', 'trying', 'started', 'go', 'already', 'court', 'far', 'ill', 'something', 'better', 'cavusoglus', 'numan', 'flexible', 'thorough', 'foreign', 'last', 'couple', 'ask', 'seen', 'great', 'change', 'weve', 'various', 'erdogan', 'different', 'represent', 'start', 'understand', 'one', 'widespread', 'monday', 'mevlut', 'goal', 'useful', 'panel', 'place', 'charged', 'certain', 'kurtulmus', 'turkey', 'enable', 'model', 'minute', 'technology', 'test', 'invasion', 'similar', 'leave', 'harder', 'justice', 'saying', 'process', 'amount', 'necessary', 'new', 'parliament', 'people', 'ankara', 'decided', 'artificial', 'citizen', 'rapidly', 'presidency', 'laundering', 'called', 'point', 'islamic', 'prosecution', 'efrem', 'let', 'case', 'editor', 'within', 'year', 'everything', 'find', 'together', 'get', 'around', 'best', 'type', 'look', 'intelligence', 'way', 'revolution', 'become', 'still', 'wont', 'thing', 'solved', 'history', 'opposition', 'learning', 'possible', 'background', 'money', 'meanwhile', 'introduce', 'problem', 'charge', 'east', 'answer', 'agreed', 'historical', 'user', 'finding', 'relevant'}
# 232

# %% [markdown]
# # **Using Scikit-learn TF-IDF Calculation (Built-In)**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
import math

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(full_corpus)
feature_names = tfidf_vectorizer.get_feature_names_out()
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)
print("TF-IDF Built-in DataFrame:")
print(tfidf_df)
# Out:
# TF-IDF Built-in DataFrame:
#     accused    agreed     ahead       aim   already      also    amount  \
# 0  0.074951  0.074951  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.038388  0.038388  0.076775  0.038388  0.038388
#
#       anger    ankara    answer  ...      well      weve   whether  \
# 0  0.074951  0.074951  0.000000  ...  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.038388  ...  0.038388  0.038388  0.038388
#
#    widespread    within      wont   working     world      year  yildirim
# 0    0.074951  0.000000  0.000000  0.000000  0.000000  0.074951  0.074951
# 1    0.000000  0.038388  0.038388  0.076775  0.038388  0.000000  0.000000
#
# [2 rows x 231 columns]

# %% [markdown]
# # **Trying to implement TF-IDF From Scratch**

# %%
def calculate_tf(full_corpus):
    tf_df = pd.DataFrame()

    #loop over documents in the corpus
    for i, document in enumerate(full_corpus):
        words = document.split()

        #total number of words
        total_words = len(words)

        #calculating frequency of each word
        word_freq = {}
        for word in set(words):
          word_freq[word] = words.count(word) / total_words

        #each row for each document
        tf_df = tf_df.append(word_freq, ignore_index=True)

    #equal NaN = 0
    tf_df = tf_df.fillna(0)

    return tf_df

# %%
tf_calculation = calculate_tf(full_corpus)
tf_calculation
# Out:
# <ipython-input-105-66be15b8b3a6>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(word_freq, ignore_index=True)
# <ipython-input-105-66be15b8b3a6>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(word_freq, ignore_index=True)
#       anger   protect      iraq  resulted      need      city  newspaper  \
# 0  0.008696  0.008696  0.008696  0.008696  0.008696  0.008696   0.008696
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
#
#    instance  investigative   sparked  ...    become      wont     thing  \
# 0  0.008696       0.008696  0.008696  ...  0.000000  0.000000  0.000000
# 1  0.000000       0.000000  0.000000  ...  0.004274  0.004274  0.017094
#
#    learning  possible  background  introduce    answer      user  relevant
# 0  0.000000  0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 1  0.004274  0.004274    0.004274   0.004274  0.004274  0.004274  0.012821
#
# [2 rows x 232 columns]

# %%
def calculate_idf(full_corpus):
    #total number of documents in corpus
    total_docs = len(full_corpus)

    idf_values = {}

    #loop over documents
    for document in full_corpus:
        words = set(document.split())

        #update idf_values dict {}
        for word in words:
            idf_values[word] = idf_values.get(word, 0) + 1

    #calculating idf
    for word, freq in idf_values.items():
        idf_values[word] = np.log(total_docs / 1 + freq)

    return idf_values

# %%
idf_calculation = calculate_idf(full_corpus)
idf_calculation
# Out:
# {'anger': 1.0986122886681098,
#  'protect': 1.0986122886681098,
#  'iraq': 1.0986122886681098,
#  'resulted': 1.0986122886681098,
#  'need': 1.0986122886681098,
#  'city': 1.0986122886681098,
#  'newspaper': 1.0986122886681098,
#  'instance': 1.0986122886681098,
#  'investigative': 1.0986122886681098,
#  'sparked': 1.0986122886681098,
#  'middle': 1.0986122886681098,
#  'ozbilic': 1.0986122886681098,
#  'yildirim': 1.0986122886681098,
#  'committee': 1.0986122886681098,
#  'country': 1.0986122886681098,
#  'judicial': 1.0986122886681098,
#  'attempt': 1.0986122886681098,
#  'decision': 1.0986122886681098,
#  'said': 1.0986122886681098,
#  'support': 1.0986122886681098,
#  'former': 1.0986122886681098,
#  'critic': 1.0986122886681098,
#  'course': 1.0986122886681098,
#  'meeting': 1.0986122886681098,
#  'information': 1.0986122886681098,
#  'july': 1.0986122886681098,
#  'binali': 1.0986122886681098,
#  'convene': 1.0986122886681098,
#  'headed': 1.0986122886681098,
#  'speculation': 1.0986122886681098,
#  'gaziantep': 1.0986122886681098,
#  'minister': 1.0986122886681098,
#  'inciting': 1.0986122886681098,
#  'threehour': 1.0986122886681098,
#  'accused': 1.0986122886681098,
#  'coup': 1.0986122886681098,
#  'figure': 1.0986122886681098,
#  'leaking': 1.0986122886681098,
#  'medium': 1.0986122886681098,
#  'issue': 1.0986122886681098,
#  'investigation': 1.0986122886681098,
#  'cavusoglu': 1.0986122886681098,
#  'leader': 1.0986122886681098,
#  'public': 1.0986122886681098,
#  'prominent': 1.0986122886681098,
#  'turkish': 1.0986122886681098,
#  'plot': 1.0986122886681098,
#  'corruption': 1.0986122886681098,
#  'report': 1.0986122886681098,
#  'prime': 1.0986122886681098,
#  'million': 1.0986122886681098,
#  'began': 1.0986122886681098,
#  'court': 1.0986122886681098,
#  'cavusoglus': 1.0986122886681098,
#  'numan': 1.0986122886681098,
#  'thorough': 1.3862943611198906,
#  'foreign': 1.0986122886681098,
#  'last': 1.0986122886681098,
#  'seen': 1.0986122886681098,
#  'change': 1.0986122886681098,
#  'erdogan': 1.0986122886681098,
#  'widespread': 1.0986122886681098,
#  'monday': 1.0986122886681098,
#  'mevlut': 1.0986122886681098,
#  'panel': 1.0986122886681098,
#  'charged': 1.0986122886681098,
#  'kurtulmus': 1.0986122886681098,
#  'turkey': 1.0986122886681098,
#  'invasion': 1.0986122886681098,
#  'leave': 1.0986122886681098,
#  'justice': 1.0986122886681098,
#  'process': 1.3862943611198906,
#  'parliament': 1.0986122886681098,
#  'ankara': 1.0986122886681098,
#  'citizen': 1.0986122886681098,
#  'presidency': 1.0986122886681098,
#  'laundering': 1.0986122886681098,
#  'called': 1.0986122886681098,
#  'islamic': 1.0986122886681098,
#  'prosecution': 1.0986122886681098,
#  'efrem': 1.0986122886681098,
#  'case': 1.0986122886681098,
#  'editor': 1.0986122886681098,
#  'year': 1.0986122886681098,
#  'still': 1.0986122886681098,
#  'solved': 1.0986122886681098,
#  'history': 1.0986122886681098,
#  'opposition': 1.0986122886681098,
#  'money': 1.0986122886681098,
#  'meanwhile': 1.0986122886681098,
#  'problem': 1.0986122886681098,
#  'charge': 1.0986122886681098,
#  'east': 1.0986122886681098,
#  'agreed': 1.0986122886681098,
#  'historical': 1.0986122886681098,
#  'finding': 1.0986122886681098,
#  'want': 1.0986122886681098,
#  'looking': 1.0986122886681098,
#  'collaborative': 1.0986122886681098,
#  'stage': 1.0986122886681098,
#  'benefit': 1.0986122886681098,
#  'valuable': 1.0986122886681098,
#  'pick': 1.0986122886681098,
#  'important': 1.0986122886681098,
#  'might': 1.0986122886681098,
#  'clear': 1.0986122886681098,
#  'mean': 1.0986122886681098,
#  'value': 1.0986122886681098,
#  'imply': 1.0986122886681098,
#  'help': 1.0986122886681098,
#  'leap': 1.0986122886681098,
#  'use': 1.0986122886681098,
#  'im': 1.0986122886681098,
#  'customer': 1.0986122886681098,
#  'deep': 1.0986122886681098,
#  'build': 1.0986122886681098,
#  'kind': 1.0986122886681098,
#  'focus': 1.0986122886681098,
#  'price': 1.0986122886681098,
#  'make': 1.0986122886681098,
#  'obvious': 1.0986122886681098,
#  'topic': 1.0986122886681098,
#  'time': 1.0986122886681098,
#  'going': 1.0986122886681098,
#  'experience': 1.0986122886681098,
#  'simple': 1.0986122886681098,
#  'thousand': 1.0986122886681098,
#  'lot': 1.0986122886681098,
#  'part': 1.0986122886681098,
#  'try': 1.0986122886681098,
#  'provide': 1.0986122886681098,
#  'cover': 1.0986122886681098,
#  'productive': 1.0986122886681098,
#  'talking': 1.0986122886681098,
#  'forefront': 1.0986122886681098,
#  'serve': 1.0986122886681098,
#  'data': 1.0986122886681098,
#  'primary': 1.0986122886681098,
#  'insight': 1.0986122886681098,
#  'business': 1.0986122886681098,
#  'world': 1.0986122886681098,
#  'really': 1.0986122886681098,
#  'product': 1.0986122886681098,
#  'know': 1.0986122886681098,
#  'like': 1.0986122886681098,
#  'working': 1.0986122886681098,
#  'others': 1.0986122886681098,
#  'ahead': 1.0986122886681098,
#  'thats': 1.0986122886681098,
#  'create': 1.0986122886681098,
#  'develop': 1.0986122886681098,
#  'company': 1.0986122886681098,
#  'whether': 1.0986122886681098,
#  'take': 1.0986122886681098,
#  'tried': 1.0986122886681098,
#  'idea': 1.0986122886681098,
#  'differentiate': 1.0986122886681098,
#  'first': 1.0986122886681098,
#  'talent': 1.0986122886681098,
#  'happening': 1.0986122886681098,
#  'begun': 1.0986122886681098,
#  'leverage': 1.0986122886681098,
#  'may': 1.0986122886681098,
#  'article': 1.0986122886681098,
#  'key': 1.0986122886681098,
#  'soon': 1.0986122886681098,
#  'u': 1.0986122886681098,
#  'well': 1.0986122886681098,
#  'also': 1.0986122886681098,
#  'aim': 1.0986122886681098,
#  'trying': 1.0986122886681098,
#  'started': 1.0986122886681098,
#  'go': 1.0986122886681098,
#  'already': 1.0986122886681098,
#  'far': 1.0986122886681098,
#  'ill': 1.0986122886681098,
#  'something': 1.0986122886681098,
#  'better': 1.0986122886681098,
#  'flexible': 1.0986122886681098,
#  'couple': 1.0986122886681098,
#  'ask': 1.0986122886681098,
#  'great': 1.0986122886681098,
#  'weve': 1.0986122886681098,
#  'various': 1.0986122886681098,
#  'different': 1.0986122886681098,
#  'represent': 1.0986122886681098,
#  'start': 1.0986122886681098,
#  'understand': 1.0986122886681098,
#  'one': 1.0986122886681098,
#  'goal': 1.0986122886681098,
#  'useful': 1.0986122886681098,
#  'place': 1.0986122886681098,
#  'certain': 1.0986122886681098,
#  'enable': 1.0986122886681098,
#  'model': 1.0986122886681098,
#  'minute': 1.0986122886681098,
#  'technology': 1.0986122886681098,
#  'test': 1.0986122886681098,
#  'similar': 1.0986122886681098,
#  'harder': 1.0986122886681098,
#  'saying': 1.0986122886681098,
#  'amount': 1.0986122886681098,
#  'necessary': 1.0986122886681098,
#  'new': 1.0986122886681098,
#  'people': 1.0986122886681098,
#  'decided': 1.0986122886681098,
#  'artificial': 1.0986122886681098,
#  'rapidly': 1.0986122886681098,
#  'point': 1.0986122886681098,
#  'let': 1.0986122886681098,
#  'within': 1.0986122886681098,
#  'everything': 1.0986122886681098,
#  'find': 1.0986122886681098,
#  'together': 1.0986122886681098,
#  'get': 1.0986122886681098,
#  'around': 1.0986122886681098,
#  'best': 1.0986122886681098,
#  'type': 1.0986122886681098,
#  'look': 1.0986122886681098,
#  'intelligence': 1.0986122886681098,
#  'way': 1.0986122886681098,
#  'revolution': 1.0986122886681098,
#  'become': 1.0986122886681098,
#  'wont': 1.0986122886681098,
#  'thing': 1.0986122886681098,
#  'learning': 1.0986122886681098,
#  'possible': 1.0986122886681098,
#  'background': 1.0986122886681098,
#  'introduce': 1.0986122886681098,
#  'answer': 1.0986122886681098,
#  'user': 1.0986122886681098,
#  'relevant': 1.0986122886681098}

# %%
def calculate_tfidf(tf_df, idf_values):
    #empty dataframe
    tfidf_df = tf_df.copy()

    #looping over each TF and multiplying by IDF to get TF-IDF value
    for idx, row in tfidf_df.iterrows():
        for word in tfidf_df.columns:
            tfidf_df.at[idx, word] *= idf_values[word]

    return tfidf_df

# %%
tfidf_calculation = calculate_tfidf(tf_calculation,idf_calculation)
tfidf_calculation
# Out:
#       anger   protect      iraq  resulted      need      city  newspaper  \
# 0  0.009553  0.009553  0.009553  0.009553  0.009553  0.009553   0.009553
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
#
#    instance  investigative   sparked  ...    become      wont    thing  \
# 0  0.009553       0.009553  0.009553  ...  0.000000  0.000000  0.00000
# 1  0.000000       0.000000  0.000000  ...  0.004695  0.004695  0.01878
#
#    learning  possible  background  introduce    answer      user  relevant
# 0  0.000000  0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 1  0.004695  0.004695    0.004695   0.004695  0.004695  0.004695  0.014085
#
# [2 rows x 232 columns]
